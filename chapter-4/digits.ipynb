# %%
#hide
! conda install -c fastchan fastai
import fastbook
fastbook.setup_book()
# Out:
# ...
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Users/bob/miniconda3
#
#   added / updated specs:
#     - fastai
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     blas-1.0                   |         openblas          10 KB
#     bottleneck-1.3.5           |  py310h96f19d2_0         104 KB
#     brotli-1.0.9               |       h1c322ee_7          18 KB  fastchan
#     brotli-bin-1.0.9           |       h1c322ee_7          17 KB  fastchan
#     catalogue-2.0.7            |  py310hca03da5_0          33 KB
#     certifi-2022.12.7          |     pyhd8ed1ab_0         147 KB  fastchan
#     click-8.0.4                |  py310hca03da5_0         152 KB
#     colorama-0.4.6             |     pyhd8ed1ab_0          25 KB  fastchan
#     contourpy-1.0.5            |  py310h525c30c_0         199 KB
# ...

# %%
#hide
from fastai.vision.all import *
from fastbook import *
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[15], line 2
#       1 #hide
# ----> 2 from fastai.vision.all import *
#       3 from fastbook import *
#
# ModuleNotFoundError: No module named 'fastai'
